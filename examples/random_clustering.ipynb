# %%
import os
import sys

# Get the path to the `src` directory
src_path = os.path.relpath('..')
sys.path.append(src_path)

from typing import List
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

from src.types import *
from src.clustering.random import RandomClustering

# %load_ext autoreload
# %autoreload 2

# %%
T = 15

# Load data from a JSONL file
market = Market.from_jsonl("./tick_data.jsonl")

# Get periods of length 15
periods = market.get_periods(period_length=T)

clustering = RandomClustering().fit(periods, num_clusters=2)

print('-' * 50)
clustering.summarize_clusters()
print('-' * 50)
# Out:
# --------------------------------------------------
# Number of periods: 2
# Number of clusters: 2
# Cluster sizes: [1, 1]
# Cluster labels: [1 0]
# Transition matrix:
# [[1. 0.]
#  [1. 0.]]
# --------------------------------------------------

# %%
clustering.plot_ssv()
